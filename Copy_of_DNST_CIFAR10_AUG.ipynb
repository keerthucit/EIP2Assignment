# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthucit/EIP2Assignment/blob/master/Copy_of_DNST_CIFAR10_AUG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://keras.io/
# !pip install -q keras
import keras

# %%
import keras
from keras.datasets import cifar10
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Flatten, Input, AveragePooling2D, merge, Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Concatenate
#from keras.optimizers import Adam
from keras.optimizers import sgd
from keras import metrics
#import imgaug as ia
#from imgaug import augmenters as iaa
#import random
#import numpy as np
#images = np.random.randint(0, 50, (4, 128, 128, 3), dtype=np.uint8)

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# %%
# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 250
l = 100
#num_filter = 12
num_filter = 16
compression = 0.5
dropout_rate = 0.2

# %%
# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_height, img_width, channel = x_train.shape[1],x_train.shape[2],x_train.shape[3]

# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print('Training data shape : ', x_train.shape,y_train.shape)

# %%
# Dense Block
def add_denseblock(input, num_filter = 12, dropout_rate = 0.2):
    global compression
    temp = input
    for _ in range(l):
        BatchNorm = BatchNormalization()(temp)
        relu = Activation('relu')(BatchNorm)
        Conv2D_3_3 = Conv2D(int(num_filter*compression), (3,3), use_bias=False ,padding='same')(relu)
        if dropout_rate>0:
          Conv2D_3_3 = Dropout(dropout_rate)(Conv2D_3_3)
        concat = Concatenate(axis=-1)([temp,Conv2D_3_3])
        
        temp = concat
        
    return temp

# %%
def add_transition(input, num_filter = 12, dropout_rate = 0.2):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    Conv2D_BottleNeck = Conv2D(int(num_filter*compression), (1,1), use_bias=False ,padding='same')(relu)
    if dropout_rate>0:
      Conv2D_BottleNeck = Dropout(dropout_rate)(Conv2D_BottleNeck)
    avg = AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)
    
    return avg

# %%
def output_layer(input):
    global compression
    BatchNorm = BatchNormalization()(input)
    relu = Activation('relu')(BatchNorm)
    AvgPooling = AveragePooling2D(pool_size=(2,2))(relu)
    flat = Flatten()(AvgPooling)
    output = Dense(num_classes, activation='softmax')(flat)
    
    return output

# %%
num_filter = 12
dropout_rate = 0.2
l = 12
input = Input(shape=(img_height, img_width, channel,))
First_Conv2D = Conv2D(num_filter, (3,3), use_bias=False ,padding='same')(input)

First_Block = add_denseblock(First_Conv2D, num_filter, dropout_rate)
First_Transition = add_transition(First_Block, num_filter, dropout_rate)

Second_Block = add_denseblock(First_Transition, num_filter, dropout_rate)
Second_Transition = add_transition(Second_Block, num_filter, dropout_rate)

Third_Block = add_denseblock(Second_Transition, num_filter, dropout_rate)
Third_Transition = add_transition(Third_Block, num_filter, dropout_rate)

Last_Block = add_denseblock(Third_Transition,  num_filter, dropout_rate)
output = output_layer(Last_Block)

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 12)   324         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 12)   48          conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 12)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 6)    648         activation_53[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 32, 32, 6)    0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 32, 32, 18)   0           conv2d_53[0][0]
#                                                                  dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 18)   72          concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 18)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 6)    972         activation_54[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 32, 6)    0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 32, 32, 24)   0           concatenate_49[0][0]
#                                                                  dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 24)   96          concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 24)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 6)    1296        activation_55[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 32, 32, 6)    0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 32, 32, 30)   0           concatenate_50[0][0]
#                                                                  dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 30)   120         concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 32, 32, 30)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 32, 32, 6)    1620        activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 32, 32, 6)    0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 32, 32, 36)   0           concatenate_51[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 36)   144         concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 36)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 6)    1944        activation_57[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 32, 32, 6)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 32, 32, 42)   0           concatenate_52[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 42)   168         concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 42)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 6)    2268        activation_58[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 32, 32, 6)    0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 32, 32, 48)   0           concatenate_53[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 48)   192         concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 48)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 6)    2592        activation_59[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 32, 32, 6)    0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 32, 32, 54)   0           concatenate_54[0][0]
#                                                                  dropout_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 54)   216         concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 54)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 6)    2916        activation_60[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 32, 32, 6)    0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 32, 32, 60)   0           concatenate_55[0][0]
#                                                                  dropout_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 60)   240         concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 60)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 6)    3240        activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 32, 32, 6)    0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 32, 32, 66)   0           concatenate_56[0][0]
#                                                                  dropout_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 66)   264         concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 66)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 6)    3564        activation_62[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 32, 32, 6)    0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 32, 32, 72)   0           concatenate_57[0][0]
#                                                                  dropout_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 72)   288         concatenate_58[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 72)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 6)    3888        activation_63[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 32, 32, 6)    0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 32, 32, 78)   0           concatenate_58[0][0]
#                                                                  dropout_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 78)   312         concatenate_59[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 78)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 6)    4212        activation_64[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 32, 32, 6)    0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 32, 32, 84)   0           concatenate_59[0][0]
#                                                                  dropout_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 84)   336         concatenate_60[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 84)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 6)    504         activation_65[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 32, 32, 6)    0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 16, 6)    0           dropout_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 16, 16, 6)    24          average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 6)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 16, 16, 6)    324         activation_66[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 16, 16, 6)    0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 16, 16, 12)   0           average_pooling2d_5[0][0]
#                                                                  dropout_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 12)   48          concatenate_61[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 12)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 6)    648         activation_67[0][0]
# __________________________________________________________________________________________________
# dropout_66 (Dropout)            (None, 16, 16, 6)    0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 16, 16, 18)   0           concatenate_61[0][0]
#                                                                  dropout_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 18)   72          concatenate_62[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 18)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 6)    972         activation_68[0][0]
# __________________________________________________________________________________________________
# dropout_67 (Dropout)            (None, 16, 16, 6)    0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 16, 16, 24)   0           concatenate_62[0][0]
#                                                                  dropout_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 24)   96          concatenate_63[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 24)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 6)    1296        activation_69[0][0]
# __________________________________________________________________________________________________
# dropout_68 (Dropout)            (None, 16, 16, 6)    0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 16, 16, 30)   0           concatenate_63[0][0]
#                                                                  dropout_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 30)   120         concatenate_64[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 16, 30)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 16, 16, 6)    1620        activation_70[0][0]
# __________________________________________________________________________________________________
# dropout_69 (Dropout)            (None, 16, 16, 6)    0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 16, 16, 36)   0           concatenate_64[0][0]
#                                                                  dropout_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 36)   144         concatenate_65[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 16, 36)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 6)    1944        activation_71[0][0]
# __________________________________________________________________________________________________
# dropout_70 (Dropout)            (None, 16, 16, 6)    0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 16, 16, 42)   0           concatenate_65[0][0]
#                                                                  dropout_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 42)   168         concatenate_66[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 16, 16, 42)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 16, 16, 6)    2268        activation_72[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 16, 16, 6)    0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 16, 16, 48)   0           concatenate_66[0][0]
#                                                                  dropout_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 48)   192         concatenate_67[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 16, 16, 48)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 6)    2592        activation_73[0][0]
# __________________________________________________________________________________________________
# dropout_72 (Dropout)            (None, 16, 16, 6)    0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 16, 16, 54)   0           concatenate_67[0][0]
#                                                                  dropout_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 54)   216         concatenate_68[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 54)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 6)    2916        activation_74[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 16, 16, 6)    0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 16, 16, 60)   0           concatenate_68[0][0]
#                                                                  dropout_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 60)   240         concatenate_69[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 60)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 6)    3240        activation_75[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 16, 16, 6)    0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 16, 16, 66)   0           concatenate_69[0][0]
#                                                                  dropout_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 66)   264         concatenate_70[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 16, 16, 66)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 6)    3564        activation_76[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 16, 16, 6)    0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 16, 16, 72)   0           concatenate_70[0][0]
#                                                                  dropout_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 16, 16, 72)   288         concatenate_71[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 16, 16, 72)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 6)    3888        activation_77[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 16, 16, 6)    0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 16, 16, 78)   0           concatenate_71[0][0]
#                                                                  dropout_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 16, 16, 78)   312         concatenate_72[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 16, 16, 78)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 6)    468         activation_78[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 16, 16, 6)    0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 8, 8, 6)      0           dropout_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 6)      24          average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 6)      0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 6)      324         activation_79[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 8, 8, 6)      0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 8, 8, 12)     0           average_pooling2d_6[0][0]
#                                                                  dropout_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 12)     48          concatenate_73[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 12)     0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 6)      648         activation_80[0][0]
# __________________________________________________________________________________________________
# dropout_79 (Dropout)            (None, 8, 8, 6)      0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 8, 8, 18)     0           concatenate_73[0][0]
#                                                                  dropout_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 18)     72          concatenate_74[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 18)     0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 6)      972         activation_81[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 8, 8, 6)      0           conv2d_82[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 8, 8, 24)     0           concatenate_74[0][0]
#                                                                  dropout_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 24)     96          concatenate_75[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 24)     0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 6)      1296        activation_82[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 8, 8, 6)      0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 8, 8, 30)     0           concatenate_75[0][0]
#                                                                  dropout_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 30)     120         concatenate_76[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 30)     0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 6)      1620        activation_83[0][0]
# __________________________________________________________________________________________________
# dropout_82 (Dropout)            (None, 8, 8, 6)      0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 8, 8, 36)     0           concatenate_76[0][0]
#                                                                  dropout_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 36)     144         concatenate_77[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 36)     0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 6)      1944        activation_84[0][0]
# __________________________________________________________________________________________________
# dropout_83 (Dropout)            (None, 8, 8, 6)      0           conv2d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 8, 8, 42)     0           concatenate_77[0][0]
#                                                                  dropout_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 42)     168         concatenate_78[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 42)     0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 6)      2268        activation_85[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 8, 8, 6)      0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 8, 8, 48)     0           concatenate_78[0][0]
#                                                                  dropout_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 48)     192         concatenate_79[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 48)     0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 6)      2592        activation_86[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 8, 8, 6)      0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 8, 8, 54)     0           concatenate_79[0][0]
#                                                                  dropout_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 54)     216         concatenate_80[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 54)     0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 6)      2916        activation_87[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 8, 8, 6)      0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_81 (Concatenate)    (None, 8, 8, 60)     0           concatenate_80[0][0]
#                                                                  dropout_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 60)     240         concatenate_81[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 60)     0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 6)      3240        activation_88[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 8, 8, 6)      0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_82 (Concatenate)    (None, 8, 8, 66)     0           concatenate_81[0][0]
#                                                                  dropout_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 66)     264         concatenate_82[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 66)     0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 6)      3564        activation_89[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 8, 8, 6)      0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_83 (Concatenate)    (None, 8, 8, 72)     0           concatenate_82[0][0]
#                                                                  dropout_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 72)     288         concatenate_83[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 72)     0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 6)      3888        activation_90[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 8, 8, 6)      0           conv2d_91[0][0]
# __________________________________________________________________________________________________
# concatenate_84 (Concatenate)    (None, 8, 8, 78)     0           concatenate_83[0][0]
#                                                                  dropout_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 78)     312         concatenate_84[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 78)     0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 6)      468         activation_91[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 8, 8, 6)      0           conv2d_92[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 4, 4, 6)      0           dropout_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 4, 4, 6)      24          average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 4, 4, 6)      0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 4, 4, 6)      324         activation_92[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 4, 4, 6)      0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# concatenate_85 (Concatenate)    (None, 4, 4, 12)     0           average_pooling2d_7[0][0]
#                                                                  dropout_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 4, 4, 12)     48          concatenate_85[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 4, 4, 12)     0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 4, 4, 6)      648         activation_93[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 4, 4, 6)      0           conv2d_94[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 4, 4, 18)     0           concatenate_85[0][0]
#                                                                  dropout_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 4, 4, 18)     72          concatenate_86[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 4, 4, 18)     0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 4, 4, 6)      972         activation_94[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 4, 4, 6)      0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_87 (Concatenate)    (None, 4, 4, 24)     0           concatenate_86[0][0]
#                                                                  dropout_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 4, 4, 24)     96          concatenate_87[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 4, 4, 24)     0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 4, 4, 6)      1296        activation_95[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 4, 4, 6)      0           conv2d_96[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 4, 4, 30)     0           concatenate_87[0][0]
#                                                                  dropout_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 4, 4, 30)     120         concatenate_88[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 4, 4, 30)     0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 4, 4, 6)      1620        activation_96[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 4, 4, 6)      0           conv2d_97[0][0]
# __________________________________________________________________________________________________
# concatenate_89 (Concatenate)    (None, 4, 4, 36)     0           concatenate_88[0][0]
#                                                                  dropout_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 4, 4, 36)     144         concatenate_89[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 4, 4, 36)     0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 4, 4, 6)      1944        activation_97[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 4, 4, 6)      0           conv2d_98[0][0]
# __________________________________________________________________________________________________
# concatenate_90 (Concatenate)    (None, 4, 4, 42)     0           concatenate_89[0][0]
#                                                                  dropout_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 4, 4, 42)     168         concatenate_90[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 4, 4, 42)     0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 4, 4, 6)      2268        activation_98[0][0]
# __________________________________________________________________________________________________
# dropout_97 (Dropout)            (None, 4, 4, 6)      0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 4, 4, 48)     0           concatenate_90[0][0]
#                                                                  dropout_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 4, 4, 48)     192         concatenate_91[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 4, 4, 48)     0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 4, 4, 6)      2592        activation_99[0][0]
# __________________________________________________________________________________________________
# dropout_98 (Dropout)            (None, 4, 4, 6)      0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 4, 4, 54)     0           concatenate_91[0][0]
#                                                                  dropout_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 4, 4, 54)     216         concatenate_92[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 4, 4, 54)     0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 4, 4, 6)      2916        activation_100[0][0]
# __________________________________________________________________________________________________
# dropout_99 (Dropout)            (None, 4, 4, 6)      0           conv2d_101[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 4, 4, 60)     0           concatenate_92[0][0]
#                                                                  dropout_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 4, 4, 60)     240         concatenate_93[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 4, 4, 60)     0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 4, 4, 6)      3240        activation_101[0][0]
# __________________________________________________________________________________________________
# dropout_100 (Dropout)           (None, 4, 4, 6)      0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 4, 4, 66)     0           concatenate_93[0][0]
#                                                                  dropout_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 4, 4, 66)     264         concatenate_94[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 4, 4, 66)     0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 4, 4, 6)      3564        activation_102[0][0]
# __________________________________________________________________________________________________
# dropout_101 (Dropout)           (None, 4, 4, 6)      0           conv2d_103[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 4, 4, 72)     0           concatenate_94[0][0]
#                                                                  dropout_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 4, 4, 72)     288         concatenate_95[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 4, 4, 72)     0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 4, 4, 6)      3888        activation_103[0][0]
# __________________________________________________________________________________________________
# dropout_102 (Dropout)           (None, 4, 4, 6)      0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# concatenate_96 (Concatenate)    (None, 4, 4, 78)     0           concatenate_95[0][0]
#                                                                  dropout_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 4, 4, 78)     312         concatenate_96[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 4, 4, 78)     0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 2, 2, 78)     0           activation_104[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 312)          0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           3130        flatten_2[0][0]
# ==================================================================================================
# Total params: 118,918
# Trainable params: 114,394
# Non-trainable params: 4,524
# __________________________________________________________________________________________________

# %%
# determine Loss function and Optimizer
#model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
model.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=[top_k_categorical_acuracy])

# %%
model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/250
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.0924 - mean_absolute_error: 0.1788 - categorical_accuracy: 0.1123 - val_loss: 0.0903 - val_mean_absolute_error: 0.1797 - val_categorical_accuracy: 0.1048
# Epoch 2/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0910 - mean_absolute_error: 0.1783 - categorical_accuracy: 0.1221 - val_loss: 0.0899 - val_mean_absolute_error: 0.1795 - val_categorical_accuracy: 0.1062
# Epoch 3/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0901 - mean_absolute_error: 0.1775 - categorical_accuracy: 0.1341 - val_loss: 0.0895 - val_mean_absolute_error: 0.1790 - val_categorical_accuracy: 0.1250
# Epoch 4/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0892 - mean_absolute_error: 0.1766 - categorical_accuracy: 0.1510 - val_loss: 0.0889 - val_mean_absolute_error: 0.1781 - val_categorical_accuracy: 0.1490
# Epoch 5/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0886 - mean_absolute_error: 0.1757 - categorical_accuracy: 0.1612 - val_loss: 0.0884 - val_mean_absolute_error: 0.1772 - val_categorical_accuracy: 0.1578
# Epoch 6/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0883 - mean_absolute_error: 0.1752 - categorical_accuracy: 0.1726 - val_loss: 0.0880 - val_mean_absolute_error: 0.1765 - val_categorical_accuracy: 0.1641
# Epoch 7/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0880 - mean_absolute_error: 0.1747 - categorical_accuracy: 0.1793 - val_loss: 0.0877 - val_mean_absolute_error: 0.1760 - val_categorical_accuracy: 0.1700
# Epoch 8/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0876 - mean_absolute_error: 0.1743 - categorical_accuracy: 0.1880 - val_loss: 0.0875 - val_mean_absolute_error: 0.1756 - val_categorical_accuracy: 0.1722
# Epoch 9/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0874 - mean_absolute_error: 0.1738 - categorical_accuracy: 0.1957 - val_loss: 0.0872 - val_mean_absolute_error: 0.1752 - val_categorical_accuracy: 0.1752
# Epoch 10/250
# 50000/50000 [==============================] - 105s 2ms/step - loss: 0.0871 - mean_absolute_error: 0.1734 - categorical_accuracy: 0.1992 - val_loss: 0.0868 - val_mean_absolute_error: 0.1743 - val_categorical_accuracy: 0.1822
# Epoch 11/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0868 - mean_absolute_error: 0.1730 - categorical_accuracy: 0.2048 - val_loss: 0.0866 - val_mean_absolute_error: 0.1739 - val_categorical_accuracy: 0.1856
# Epoch 12/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.1727 - categorical_accuracy: 0.2072 - val_loss: 0.0864 - val_mean_absolute_error: 0.1734 - val_categorical_accuracy: 0.1887
# Epoch 13/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0863 - mean_absolute_error: 0.1722 - categorical_accuracy: 0.2128 - val_loss: 0.0862 - val_mean_absolute_error: 0.1729 - val_categorical_accuracy: 0.1946
# Epoch 14/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0861 - mean_absolute_error: 0.1717 - categorical_accuracy: 0.2181 - val_loss: 0.0859 - val_mean_absolute_error: 0.1721 - val_categorical_accuracy: 0.1974
# Epoch 15/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0856 - mean_absolute_error: 0.1710 - categorical_accuracy: 0.2258 - val_loss: 0.0858 - val_mean_absolute_error: 0.1718 - val_categorical_accuracy: 0.2004
# Epoch 16/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0855 - mean_absolute_error: 0.1707 - categorical_accuracy: 0.2266 - val_loss: 0.0856 - val_mean_absolute_error: 0.1712 - val_categorical_accuracy: 0.2025
# Epoch 17/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0852 - mean_absolute_error: 0.1701 - categorical_accuracy: 0.2295 - val_loss: 0.0854 - val_mean_absolute_error: 0.1711 - val_categorical_accuracy: 0.2024
# Epoch 18/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0849 - mean_absolute_error: 0.1696 - categorical_accuracy: 0.2329 - val_loss: 0.0853 - val_mean_absolute_error: 0.1704 - val_categorical_accuracy: 0.2059
# Epoch 19/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0847 - mean_absolute_error: 0.1692 - categorical_accuracy: 0.2374 - val_loss: 0.0850 - val_mean_absolute_error: 0.1700 - val_categorical_accuracy: 0.2097
# Epoch 20/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0844 - mean_absolute_error: 0.1687 - categorical_accuracy: 0.2433 - val_loss: 0.0848 - val_mean_absolute_error: 0.1695 - val_categorical_accuracy: 0.2138
# Epoch 21/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0841 - mean_absolute_error: 0.1681 - categorical_accuracy: 0.2456 - val_loss: 0.0847 - val_mean_absolute_error: 0.1694 - val_categorical_accuracy: 0.2152
# Epoch 22/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0838 - mean_absolute_error: 0.1677 - categorical_accuracy: 0.2470 - val_loss: 0.0843 - val_mean_absolute_error: 0.1685 - val_categorical_accuracy: 0.2251
# Epoch 23/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0835 - mean_absolute_error: 0.1671 - categorical_accuracy: 0.2536 - val_loss: 0.0842 - val_mean_absolute_error: 0.1682 - val_categorical_accuracy: 0.2269
# Epoch 24/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0834 - mean_absolute_error: 0.1668 - categorical_accuracy: 0.2524 - val_loss: 0.0839 - val_mean_absolute_error: 0.1677 - val_categorical_accuracy: 0.2368
# Epoch 25/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0831 - mean_absolute_error: 0.1663 - categorical_accuracy: 0.2582 - val_loss: 0.0840 - val_mean_absolute_error: 0.1677 - val_categorical_accuracy: 0.2326
# Epoch 26/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0828 - mean_absolute_error: 0.1658 - categorical_accuracy: 0.2614 - val_loss: 0.0839 - val_mean_absolute_error: 0.1676 - val_categorical_accuracy: 0.2339
# Epoch 27/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0827 - mean_absolute_error: 0.1655 - categorical_accuracy: 0.2646 - val_loss: 0.0839 - val_mean_absolute_error: 0.1674 - val_categorical_accuracy: 0.2353
# Epoch 28/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0824 - mean_absolute_error: 0.1651 - categorical_accuracy: 0.2648 - val_loss: 0.0838 - val_mean_absolute_error: 0.1671 - val_categorical_accuracy: 0.2364
# Epoch 29/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0823 - mean_absolute_error: 0.1649 - categorical_accuracy: 0.2662 - val_loss: 0.0831 - val_mean_absolute_error: 0.1664 - val_categorical_accuracy: 0.2488
# Epoch 30/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0820 - mean_absolute_error: 0.1643 - categorical_accuracy: 0.2706 - val_loss: 0.0831 - val_mean_absolute_error: 0.1659 - val_categorical_accuracy: 0.2477
# Epoch 31/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0819 - mean_absolute_error: 0.1641 - categorical_accuracy: 0.2722 - val_loss: 0.0831 - val_mean_absolute_error: 0.1659 - val_categorical_accuracy: 0.2461
# Epoch 32/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0817 - mean_absolute_error: 0.1637 - categorical_accuracy: 0.2768 - val_loss: 0.0827 - val_mean_absolute_error: 0.1655 - val_categorical_accuracy: 0.2521
# Epoch 33/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0815 - mean_absolute_error: 0.1634 - categorical_accuracy: 0.2783 - val_loss: 0.0827 - val_mean_absolute_error: 0.1654 - val_categorical_accuracy: 0.2517
# Epoch 34/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0813 - mean_absolute_error: 0.1631 - categorical_accuracy: 0.2813 - val_loss: 0.0822 - val_mean_absolute_error: 0.1641 - val_categorical_accuracy: 0.2621
# Epoch 35/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0811 - mean_absolute_error: 0.1627 - categorical_accuracy: 0.2868 - val_loss: 0.0822 - val_mean_absolute_error: 0.1641 - val_categorical_accuracy: 0.2613
# Epoch 36/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0811 - mean_absolute_error: 0.1625 - categorical_accuracy: 0.2848 - val_loss: 0.0829 - val_mean_absolute_error: 0.1656 - val_categorical_accuracy: 0.2465
# Epoch 37/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0809 - mean_absolute_error: 0.1623 - categorical_accuracy: 0.2883 - val_loss: 0.0824 - val_mean_absolute_error: 0.1646 - val_categorical_accuracy: 0.2550
# Epoch 38/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0808 - mean_absolute_error: 0.1620 - categorical_accuracy: 0.2919 - val_loss: 0.0824 - val_mean_absolute_error: 0.1641 - val_categorical_accuracy: 0.2564
# Epoch 39/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0807 - mean_absolute_error: 0.1619 - categorical_accuracy: 0.2922 - val_loss: 0.0813 - val_mean_absolute_error: 0.1625 - val_categorical_accuracy: 0.2769
# Epoch 40/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0804 - mean_absolute_error: 0.1614 - categorical_accuracy: 0.2918 - val_loss: 0.0818 - val_mean_absolute_error: 0.1636 - val_categorical_accuracy: 0.2640
# Epoch 41/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0804 - mean_absolute_error: 0.1613 - categorical_accuracy: 0.2960 - val_loss: 0.0811 - val_mean_absolute_error: 0.1621 - val_categorical_accuracy: 0.2786
# Epoch 42/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0803 - mean_absolute_error: 0.1611 - categorical_accuracy: 0.2970 - val_loss: 0.0824 - val_mean_absolute_error: 0.1642 - val_categorical_accuracy: 0.2536
# Epoch 43/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0801 - mean_absolute_error: 0.1609 - categorical_accuracy: 0.2988 - val_loss: 0.0806 - val_mean_absolute_error: 0.1612 - val_categorical_accuracy: 0.2865
# Epoch 44/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0800 - mean_absolute_error: 0.1606 - categorical_accuracy: 0.3025 - val_loss: 0.0815 - val_mean_absolute_error: 0.1625 - val_categorical_accuracy: 0.2700
# Epoch 45/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0798 - mean_absolute_error: 0.1603 - categorical_accuracy: 0.3025 - val_loss: 0.0803 - val_mean_absolute_error: 0.1605 - val_categorical_accuracy: 0.2909
# Epoch 46/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0797 - mean_absolute_error: 0.1601 - categorical_accuracy: 0.3048 - val_loss: 0.0806 - val_mean_absolute_error: 0.1607 - val_categorical_accuracy: 0.2867
# Epoch 47/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0796 - mean_absolute_error: 0.1599 - categorical_accuracy: 0.3071 - val_loss: 0.0801 - val_mean_absolute_error: 0.1597 - val_categorical_accuracy: 0.2949
# Epoch 48/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0795 - mean_absolute_error: 0.1597 - categorical_accuracy: 0.3081 - val_loss: 0.0803 - val_mean_absolute_error: 0.1603 - val_categorical_accuracy: 0.2910
# Epoch 49/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0794 - mean_absolute_error: 0.1595 - categorical_accuracy: 0.3089 - val_loss: 0.0808 - val_mean_absolute_error: 0.1611 - val_categorical_accuracy: 0.2820
# Epoch 50/250
# 50000/50000 [==============================] - 107s 2ms/step - loss: 0.0794 - mean_absolute_error: 0.1594 - categorical_accuracy: 0.3115 - val_loss: 0.0807 - val_mean_absolute_error: 0.1607 - val_categorical_accuracy: 0.2837
# Epoch 51/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0792 - mean_absolute_error: 0.1592 - categorical_accuracy: 0.3120 - val_loss: 0.0798 - val_mean_absolute_error: 0.1592 - val_categorical_accuracy: 0.2989
# Epoch 52/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0790 - mean_absolute_error: 0.1588 - categorical_accuracy: 0.3131 - val_loss: 0.0803 - val_mean_absolute_error: 0.1602 - val_categorical_accuracy: 0.2894
# Epoch 53/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0790 - mean_absolute_error: 0.1587 - categorical_accuracy: 0.3141 - val_loss: 0.0811 - val_mean_absolute_error: 0.1611 - val_categorical_accuracy: 0.2735
# Epoch 54/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0788 - mean_absolute_error: 0.1584 - categorical_accuracy: 0.3200 - val_loss: 0.0798 - val_mean_absolute_error: 0.1594 - val_categorical_accuracy: 0.2965
# Epoch 55/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0786 - mean_absolute_error: 0.1582 - categorical_accuracy: 0.3213 - val_loss: 0.0796 - val_mean_absolute_error: 0.1589 - val_categorical_accuracy: 0.2998
# Epoch 56/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0786 - mean_absolute_error: 0.1580 - categorical_accuracy: 0.3225 - val_loss: 0.0796 - val_mean_absolute_error: 0.1583 - val_categorical_accuracy: 0.3005
# Epoch 57/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0785 - mean_absolute_error: 0.1578 - categorical_accuracy: 0.3217 - val_loss: 0.0787 - val_mean_absolute_error: 0.1567 - val_categorical_accuracy: 0.3152
# Epoch 58/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0783 - mean_absolute_error: 0.1576 - categorical_accuracy: 0.3229 - val_loss: 0.0790 - val_mean_absolute_error: 0.1572 - val_categorical_accuracy: 0.3093
# Epoch 59/250
# 50000/50000 [==============================] - 105s 2ms/step - loss: 0.0783 - mean_absolute_error: 0.1574 - categorical_accuracy: 0.3268 - val_loss: 0.0794 - val_mean_absolute_error: 0.1587 - val_categorical_accuracy: 0.2996
# Epoch 60/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0782 - mean_absolute_error: 0.1572 - categorical_accuracy: 0.3261 - val_loss: 0.0787 - val_mean_absolute_error: 0.1568 - val_categorical_accuracy: 0.3109
# Epoch 61/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0781 - mean_absolute_error: 0.1570 - categorical_accuracy: 0.3291 - val_loss: 0.0790 - val_mean_absolute_error: 0.1574 - val_categorical_accuracy: 0.3060
# Epoch 62/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0779 - mean_absolute_error: 0.1567 - categorical_accuracy: 0.3311 - val_loss: 0.0805 - val_mean_absolute_error: 0.1598 - val_categorical_accuracy: 0.2785
# Epoch 63/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0778 - mean_absolute_error: 0.1565 - categorical_accuracy: 0.3304 - val_loss: 0.0786 - val_mean_absolute_error: 0.1559 - val_categorical_accuracy: 0.3118
# Epoch 64/250
# 50000/50000 [==============================] - 105s 2ms/step - loss: 0.0777 - mean_absolute_error: 0.1564 - categorical_accuracy: 0.3309 - val_loss: 0.0790 - val_mean_absolute_error: 0.1572 - val_categorical_accuracy: 0.3067
# Epoch 65/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0777 - mean_absolute_error: 0.1563 - categorical_accuracy: 0.3319 - val_loss: 0.0801 - val_mean_absolute_error: 0.1585 - val_categorical_accuracy: 0.2872
# Epoch 66/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0776 - mean_absolute_error: 0.1561 - categorical_accuracy: 0.3330 - val_loss: 0.0791 - val_mean_absolute_error: 0.1571 - val_categorical_accuracy: 0.3033
# Epoch 67/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0773 - mean_absolute_error: 0.1557 - categorical_accuracy: 0.3384 - val_loss: 0.0775 - val_mean_absolute_error: 0.1545 - val_categorical_accuracy: 0.3264
# Epoch 68/250
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.0773 - mean_absolute_error: 0.1556 - categorical_accuracy: 0.3361 - val_loss: 0.0791 - val_mean_absolute_error: 0.1571 - val_categorical_accuracy: 0.3016
# Epoch 69/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0771 - mean_absolute_error: 0.1553 - categorical_accuracy: 0.3406 - val_loss: 0.0798 - val_mean_absolute_error: 0.1584 - val_categorical_accuracy: 0.2909
# Epoch 70/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0770 - mean_absolute_error: 0.1551 - categorical_accuracy: 0.3412 - val_loss: 0.0781 - val_mean_absolute_error: 0.1555 - val_categorical_accuracy: 0.3181
# Epoch 71/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0769 - mean_absolute_error: 0.1548 - categorical_accuracy: 0.3424 - val_loss: 0.0777 - val_mean_absolute_error: 0.1549 - val_categorical_accuracy: 0.3219
# Epoch 72/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0769 - mean_absolute_error: 0.1548 - categorical_accuracy: 0.3431 - val_loss: 0.0776 - val_mean_absolute_error: 0.1554 - val_categorical_accuracy: 0.3216
# Epoch 73/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0768 - mean_absolute_error: 0.1546 - categorical_accuracy: 0.3451 - val_loss: 0.0779 - val_mean_absolute_error: 0.1545 - val_categorical_accuracy: 0.3182
# Epoch 74/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0767 - mean_absolute_error: 0.1544 - categorical_accuracy: 0.3457 - val_loss: 0.0775 - val_mean_absolute_error: 0.1530 - val_categorical_accuracy: 0.3289
# Epoch 75/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0766 - mean_absolute_error: 0.1543 - categorical_accuracy: 0.3467 - val_loss: 0.0781 - val_mean_absolute_error: 0.1546 - val_categorical_accuracy: 0.3185
# Epoch 76/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0766 - mean_absolute_error: 0.1541 - categorical_accuracy: 0.3469 - val_loss: 0.0784 - val_mean_absolute_error: 0.1551 - val_categorical_accuracy: 0.3128
# Epoch 77/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0764 - mean_absolute_error: 0.1538 - categorical_accuracy: 0.3477 - val_loss: 0.0788 - val_mean_absolute_error: 0.1563 - val_categorical_accuracy: 0.3054
# Epoch 78/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0763 - mean_absolute_error: 0.1536 - categorical_accuracy: 0.3516 - val_loss: 0.0768 - val_mean_absolute_error: 0.1525 - val_categorical_accuracy: 0.3356
# Epoch 79/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0762 - mean_absolute_error: 0.1534 - categorical_accuracy: 0.3529 - val_loss: 0.0781 - val_mean_absolute_error: 0.1551 - val_categorical_accuracy: 0.3141
# Epoch 80/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0761 - mean_absolute_error: 0.1533 - categorical_accuracy: 0.3544 - val_loss: 0.0776 - val_mean_absolute_error: 0.1529 - val_categorical_accuracy: 0.3270
# Epoch 81/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0760 - mean_absolute_error: 0.1531 - categorical_accuracy: 0.3518 - val_loss: 0.0780 - val_mean_absolute_error: 0.1548 - val_categorical_accuracy: 0.3156
# Epoch 82/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0759 - mean_absolute_error: 0.1529 - categorical_accuracy: 0.3561 - val_loss: 0.0764 - val_mean_absolute_error: 0.1516 - val_categorical_accuracy: 0.3408
# Epoch 83/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0758 - mean_absolute_error: 0.1527 - categorical_accuracy: 0.3569 - val_loss: 0.0770 - val_mean_absolute_error: 0.1523 - val_categorical_accuracy: 0.3323
# Epoch 84/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0759 - mean_absolute_error: 0.1527 - categorical_accuracy: 0.3558 - val_loss: 0.0796 - val_mean_absolute_error: 0.1571 - val_categorical_accuracy: 0.2940
# Epoch 85/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0757 - mean_absolute_error: 0.1525 - categorical_accuracy: 0.3572 - val_loss: 0.0760 - val_mean_absolute_error: 0.1503 - val_categorical_accuracy: 0.3495
# Epoch 86/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0757 - mean_absolute_error: 0.1524 - categorical_accuracy: 0.3596 - val_loss: 0.0772 - val_mean_absolute_error: 0.1523 - val_categorical_accuracy: 0.3312
# Epoch 87/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0756 - mean_absolute_error: 0.1523 - categorical_accuracy: 0.3594 - val_loss: 0.0773 - val_mean_absolute_error: 0.1519 - val_categorical_accuracy: 0.3328
# Epoch 88/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0755 - mean_absolute_error: 0.1520 - categorical_accuracy: 0.3612 - val_loss: 0.0765 - val_mean_absolute_error: 0.1505 - val_categorical_accuracy: 0.3446
# Epoch 89/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0754 - mean_absolute_error: 0.1518 - categorical_accuracy: 0.3650 - val_loss: 0.0767 - val_mean_absolute_error: 0.1507 - val_categorical_accuracy: 0.3424
# Epoch 90/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0752 - mean_absolute_error: 0.1515 - categorical_accuracy: 0.3621 - val_loss: 0.0774 - val_mean_absolute_error: 0.1523 - val_categorical_accuracy: 0.3292
# Epoch 91/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0751 - mean_absolute_error: 0.1514 - categorical_accuracy: 0.3674 - val_loss: 0.0761 - val_mean_absolute_error: 0.1502 - val_categorical_accuracy: 0.3476
# Epoch 92/250
# 50000/50000 [==============================] - 106s 2ms/step - loss: 0.0751 - mean_absolute_error: 0.1513 - categorical_accuracy: 0.3667 - val_loss: 0.0780 - val_mean_absolute_error: 0.1542 - val_categorical_accuracy: 0.3209
# Epoch 93/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0748 - mean_absolute_error: 0.1509 - categorical_accuracy: 0.3703 - val_loss: 0.0760 - val_mean_absolute_error: 0.1493 - val_categorical_accuracy: 0.3510
# Epoch 94/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0747 - mean_absolute_error: 0.1507 - categorical_accuracy: 0.3705 - val_loss: 0.0768 - val_mean_absolute_error: 0.1511 - val_categorical_accuracy: 0.3402
# Epoch 95/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0748 - mean_absolute_error: 0.1507 - categorical_accuracy: 0.3703 - val_loss: 0.0767 - val_mean_absolute_error: 0.1511 - val_categorical_accuracy: 0.3395
# Epoch 96/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0747 - mean_absolute_error: 0.1505 - categorical_accuracy: 0.3711 - val_loss: 0.0763 - val_mean_absolute_error: 0.1490 - val_categorical_accuracy: 0.3531
# Epoch 97/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0745 - mean_absolute_error: 0.1502 - categorical_accuracy: 0.3764 - val_loss: 0.0769 - val_mean_absolute_error: 0.1512 - val_categorical_accuracy: 0.3377
# Epoch 98/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0746 - mean_absolute_error: 0.1502 - categorical_accuracy: 0.3740 - val_loss: 0.0767 - val_mean_absolute_error: 0.1507 - val_categorical_accuracy: 0.3407
# Epoch 99/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0745 - mean_absolute_error: 0.1501 - categorical_accuracy: 0.3729 - val_loss: 0.0772 - val_mean_absolute_error: 0.1508 - val_categorical_accuracy: 0.3356
# Epoch 100/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0744 - mean_absolute_error: 0.1498 - categorical_accuracy: 0.3752 - val_loss: 0.0758 - val_mean_absolute_error: 0.1496 - val_categorical_accuracy: 0.3538
# Epoch 101/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0742 - mean_absolute_error: 0.1496 - categorical_accuracy: 0.3781 - val_loss: 0.0765 - val_mean_absolute_error: 0.1489 - val_categorical_accuracy: 0.3474
# Epoch 102/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0742 - mean_absolute_error: 0.1495 - categorical_accuracy: 0.3770 - val_loss: 0.0765 - val_mean_absolute_error: 0.1492 - val_categorical_accuracy: 0.3459
# Epoch 103/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0741 - mean_absolute_error: 0.1493 - categorical_accuracy: 0.3809 - val_loss: 0.0781 - val_mean_absolute_error: 0.1527 - val_categorical_accuracy: 0.3257
# Epoch 104/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0741 - mean_absolute_error: 0.1492 - categorical_accuracy: 0.3788 - val_loss: 0.0762 - val_mean_absolute_error: 0.1496 - val_categorical_accuracy: 0.3479
# Epoch 105/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0739 - mean_absolute_error: 0.1490 - categorical_accuracy: 0.3819 - val_loss: 0.0756 - val_mean_absolute_error: 0.1479 - val_categorical_accuracy: 0.3588
# Epoch 106/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0739 - mean_absolute_error: 0.1489 - categorical_accuracy: 0.3810 - val_loss: 0.0759 - val_mean_absolute_error: 0.1482 - val_categorical_accuracy: 0.3539
# Epoch 107/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0738 - mean_absolute_error: 0.1487 - categorical_accuracy: 0.3829 - val_loss: 0.0758 - val_mean_absolute_error: 0.1486 - val_categorical_accuracy: 0.3525
# Epoch 108/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0738 - mean_absolute_error: 0.1486 - categorical_accuracy: 0.3838 - val_loss: 0.0771 - val_mean_absolute_error: 0.1507 - val_categorical_accuracy: 0.3393
# Epoch 109/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0737 - mean_absolute_error: 0.1485 - categorical_accuracy: 0.3857 - val_loss: 0.0782 - val_mean_absolute_error: 0.1515 - val_categorical_accuracy: 0.3265
# Epoch 110/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0735 - mean_absolute_error: 0.1482 - categorical_accuracy: 0.3866 - val_loss: 0.0750 - val_mean_absolute_error: 0.1463 - val_categorical_accuracy: 0.3634
# Epoch 111/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0735 - mean_absolute_error: 0.1481 - categorical_accuracy: 0.3901 - val_loss: 0.0769 - val_mean_absolute_error: 0.1501 - val_categorical_accuracy: 0.3432
# Epoch 112/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0733 - mean_absolute_error: 0.1478 - categorical_accuracy: 0.3905 - val_loss: 0.0766 - val_mean_absolute_error: 0.1495 - val_categorical_accuracy: 0.3448
# Epoch 113/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0734 - mean_absolute_error: 0.1479 - categorical_accuracy: 0.3888 - val_loss: 0.0761 - val_mean_absolute_error: 0.1476 - val_categorical_accuracy: 0.3547
# Epoch 114/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0732 - mean_absolute_error: 0.1475 - categorical_accuracy: 0.3917 - val_loss: 0.0752 - val_mean_absolute_error: 0.1466 - val_categorical_accuracy: 0.3604
# Epoch 115/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0732 - mean_absolute_error: 0.1474 - categorical_accuracy: 0.3911 - val_loss: 0.0768 - val_mean_absolute_error: 0.1498 - val_categorical_accuracy: 0.3432
# Epoch 116/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0732 - mean_absolute_error: 0.1474 - categorical_accuracy: 0.3922 - val_loss: 0.0754 - val_mean_absolute_error: 0.1455 - val_categorical_accuracy: 0.3646
# Epoch 117/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0731 - mean_absolute_error: 0.1472 - categorical_accuracy: 0.3918 - val_loss: 0.0767 - val_mean_absolute_error: 0.1482 - val_categorical_accuracy: 0.3483
# Epoch 118/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0729 - mean_absolute_error: 0.1469 - categorical_accuracy: 0.3965 - val_loss: 0.0759 - val_mean_absolute_error: 0.1477 - val_categorical_accuracy: 0.3555
# Epoch 119/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0730 - mean_absolute_error: 0.1469 - categorical_accuracy: 0.3925 - val_loss: 0.0752 - val_mean_absolute_error: 0.1461 - val_categorical_accuracy: 0.3654
# Epoch 120/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0729 - mean_absolute_error: 0.1467 - categorical_accuracy: 0.3921 - val_loss: 0.0748 - val_mean_absolute_error: 0.1447 - val_categorical_accuracy: 0.3721
# Epoch 121/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0728 - mean_absolute_error: 0.1466 - categorical_accuracy: 0.3969 - val_loss: 0.0745 - val_mean_absolute_error: 0.1431 - val_categorical_accuracy: 0.3785
# Epoch 122/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0726 - mean_absolute_error: 0.1463 - categorical_accuracy: 0.3987 - val_loss: 0.0753 - val_mean_absolute_error: 0.1462 - val_categorical_accuracy: 0.3653
# Epoch 123/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0725 - mean_absolute_error: 0.1462 - categorical_accuracy: 0.3973 - val_loss: 0.0768 - val_mean_absolute_error: 0.1449 - val_categorical_accuracy: 0.3580
# Epoch 124/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0726 - mean_absolute_error: 0.1461 - categorical_accuracy: 0.3998 - val_loss: 0.0753 - val_mean_absolute_error: 0.1450 - val_categorical_accuracy: 0.3686
# Epoch 125/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0726 - mean_absolute_error: 0.1460 - categorical_accuracy: 0.3991 - val_loss: 0.0748 - val_mean_absolute_error: 0.1445 - val_categorical_accuracy: 0.3758
# Epoch 126/250
# 50000/50000 [==============================] - 103s 2ms/step - loss: 0.0725 - mean_absolute_error: 0.1459 - categorical_accuracy: 0.3985 - val_loss: 0.0766 - val_mean_absolute_error: 0.1478 - val_categorical_accuracy: 0.3520
# Epoch 127/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0724 - mean_absolute_error: 0.1457 - categorical_accuracy: 0.4029 - val_loss: 0.0757 - val_mean_absolute_error: 0.1450 - val_categorical_accuracy: 0.3629
# Epoch 128/250
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.0722 - mean_absolute_error: 0.1454 - categorical_accuracy: 0.4046 - val_loss: 0.0740 - val_mean_absolute_error: 0.1419 - val_categorical_accuracy: 0.3840
# Epoch 129/250
# 32640/50000 [==================>...........] - ETA: 33s - loss: 0.0722 - mean_absolute_error: 0.1454 - categorical_accuracy: 0.4062Buffered data was truncated after reaching the output size limit.

# %%
# Test the model
score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
# Save the trained weights in to .h5 format
model.save_weights("DNST_model.h5")
print("Saved model to disk")

# %%
from google.colab import files

files.download('DNST_model.h5')

# %%
print ((model.get_weights()))
